# %%
# !pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(777)

# %%
full_df = pd.read_csv('data/star_classification.csv')

# %%
size = len(full_df.index)

# %%
df = full_df.sample(int(size/10))
df.to_csv('data/star_classification_10.csv')

# %%
df.columns
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
#        'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'class', 'redshift',
#        'plate', 'MJD', 'fiber_ID'],
#       dtype='object')

# %%
X_full = df.loc[:, df.columns != 'class']
y = df['class']

# %%
X_full.describe()
# Out:
#              obj_ID         alpha         delta             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237665e+18    177.012948     24.238264     22.048933     20.610557
# std    8.498652e+12     96.908939     19.595958      2.241045      2.028274
# min    1.237646e+18      0.013337    -17.433946     14.151990     10.730970
# 25%    1.237659e+18    127.137128      5.551182     20.333015     18.982087
# 50%    1.237663e+18    180.936260     23.701620     22.133220     21.085140
# 75%    1.237668e+18    232.981945     40.284511     23.609695     22.107055
# max    1.237681e+18    359.958118     82.947622     27.811240     27.532110
#
#                   r             i             z        run_ID  rerun_ID  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.0
# mean      19.631032     19.075814     18.756601   4506.508900     301.0
# std        1.857609      1.758920      1.765398   1978.754121       0.0
# min        9.822070      9.469903      9.612333    109.000000     301.0
# 25%       18.143575     17.747725     17.463785   3187.000000     301.0
# 50%       20.106915     19.402090     19.000280   4192.000000     301.0
# 75%       21.031005     20.404990     19.905833   5330.000000     301.0
# max       27.334760     24.473360     24.782730   8162.000000     301.0
#
#             cam_col      field_ID   spec_obj_ID      redshift         plate  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       3.486200    186.319600  5.787696e+18      0.584338   5140.397800
# std        1.584759    146.735887  3.313576e+18      0.745315   2943.031219
# min        1.000000     11.000000  3.085832e+17     -0.006863    274.000000
# 25%        2.000000     83.000000  2.831996e+18      0.057078   2515.250000
# 50%        3.000000    147.000000  5.652167e+18      0.422845   5020.000000
# 75%        5.000000    242.000000  8.325291e+18      0.712961   7394.250000
# max        6.000000    989.000000  1.412684e+19      6.867749  12547.000000
#
#               MJD     fiber_ID
# count  10000.0000  10000.00000
# mean   55589.1266    445.75930
# std     1803.7146    272.51705
# min    51609.0000      1.00000
# 25%    54208.0000    217.00000
# 50%    55894.0000    426.00000
# 75%    56780.0000    642.00000
# max    58932.0000   1000.00000

# %%
X = X_full[['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'plate']]
X.describe()
# Out:
#              obj_ID         alpha         delta             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237665e+18    177.012948     24.238264     22.048933     20.610557
# std    8.498652e+12     96.908939     19.595958      2.241045      2.028274
# min    1.237646e+18      0.013337    -17.433946     14.151990     10.730970
# 25%    1.237659e+18    127.137128      5.551182     20.333015     18.982087
# 50%    1.237663e+18    180.936260     23.701620     22.133220     21.085140
# 75%    1.237668e+18    232.981945     40.284511     23.609695     22.107055
# max    1.237681e+18    359.958118     82.947622     27.811240     27.532110
#
#                   r             i             z      redshift         plate
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      19.631032     19.075814     18.756601      0.584338   5140.397800
# std        1.857609      1.758920      1.765398      0.745315   2943.031219
# min        9.822070      9.469903      9.612333     -0.006863    274.000000
# 25%       18.143575     17.747725     17.463785      0.057078   2515.250000
# 50%       20.106915     19.402090     19.000280      0.422845   5020.000000
# 75%       21.031005     20.404990     19.905833      0.712961   7394.250000
# max       27.334760     24.473360     24.782730      6.867749  12547.000000
