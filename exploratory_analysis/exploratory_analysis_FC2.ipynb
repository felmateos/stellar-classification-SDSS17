# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('..\data\preprocessed\_10_drp_outl_ohe.csv', index_col='obj_ID')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Felipe Castro\AppData\Local\Temp\ipykernel_17856\4226864242.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('..\data\preprocessed\_10_drp_outl_ohe.csv', index_col='obj_ID')
#                    alpha      delta         u         g         r         i  \
# obj_ID
# 1.237663e+18   15.342907   0.794882  18.74547  17.49025  16.89122  16.57350
# 1.237664e+18  120.365538  55.660432  19.99985  19.68133  19.50156  19.17364
# 1.237655e+18  245.610038  42.974786  23.11792  20.81292  18.88351  18.12335
# 1.237660e+18  127.957356   6.647703  21.94454  21.01012  20.93496  20.93184
# 1.237665e+18  159.174526  35.881846  18.89945  17.68422  17.02925  16.60000
#
#                      z  redshift  class_GALAXY  class_QSO  class_STAR
# obj_ID
# 1.237663e+18  16.29910  0.042002          True      False       False
# 1.237664e+18  19.16122  1.633797         False       True       False
# 1.237655e+18  17.68182  0.454852          True      False       False
# 1.237660e+18  20.56855  2.608515         False       True       False
# 1.237665e+18  16.36798  0.083804          True      False       False

# %%
correlation_matrix = df.corr()

# Plotar o heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Matriz de Correlação com Heatmap')
plt.show()
